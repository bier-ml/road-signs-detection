# %%
import torch
from PIL import Image
import requests
import io


class RoadSignsDetectionProcessor:
    def __init__(self, image):
        self.model = torch.hub.load('ultralytics/yolov5', 'custom', path='../models/best.pt')
        self.image = image

    def process(self):
        results = self.model([self.image], size=640)
        results.print()
        results.show()

        print(results)

# %%
url = 'https://ultralytics.com/images/zidane.jpg'
r = requests.get('https://c8.alamy.com/comp/H75165/pedestrian-crossing-square-blue-and-white-road-sign-on-metal-pole-H75165.jpg', stream=True)

img = Image.open(io.BytesIO(r.content))
p = RoadSignsDetectionProcessor(img)

p.process()
# Out:
# Using cache found in /home/slfdstrctd/.cache/torch/hub/ultralytics_yolov5_master
# YOLOv5 🚀 2023-11-23 Python-3.10.12 torch-2.1.1+cu121 CUDA:0 (NVIDIA GeForce RTX 3070 Laptop GPU, 8192MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7020913 parameters, 0 gradients, 15.8 GFLOPs
# Adding AutoShape...
# WARNING ⚠️ NMS time limit 0.550s exceeded
# image 1/1: 1390x877 1 crosswalk
# Speed: 15.5ms pre-process, 134.3ms inference, 923.6ms NMS per image at shape (1, 3, 640, 416)
# <PIL.Image.Image image mode=RGB size=877x1390>
# image 1/1: 1390x877 1 crosswalk
# Speed: 15.5ms pre-process, 134.3ms inference, 923.6ms NMS per image at shape (1, 3, 640, 416)
